# %% [markdown]
# # Feature Transformations

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats

# %% [markdown]
# ## Learning Objectives

# %% [markdown]
# - Use correlations and other algorithms to inform feature selection
# - Create new features for use in modeling
#     - Use binning to turn numerical into categorical features
#     - Use `PolynomialFeatures` to build compound features

# %% [markdown]
# ## Model Selection

# %% [markdown]
# Let's imagine that I'm going to try to predict wine quality based on the other features.

# %%
wine = pd.read_csv('data/wine.csv')

# %%
wine.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
# 5                 13.0                  40.0   0.9978  3.51       0.56
# 6                 15.0                  59.0   0.9964  3.30       0.46
# 7                 15.0                  21.0   0.9946  3.39       0.47
# 8                  9.0                  18.0   0.9968  3.36       0.57
# 9                 17.0                 102.0   0.9978  3.35       0.80
#
#    alcohol  quality  red_wine
# 0      9.4        5         1
# 1      9.8        5         1
# 2      9.8        5         1
# 3      9.8        6         1
# 4      9.4        5         1
# 5      9.4        5         1
# 6      9.4        5         1
# 7     10.0        7         1
# 8      9.5        7         1
# 9     10.5        5         1

# %% [markdown]
# ## Decisions, Decisions, Decisions...

# %% [markdown]
# Now: Which columns (predictors) should I choose?
#
# There are 12 predictors I could choose from. For each of these predictors, I could either use it or not use it in my model, which means that there are $2^{12} = 4096$ _different_ models I could construct! Well, okay, one of these is the "empty model" with no predictors in it. But there are still 4095 models from which I can choose.

# %% [markdown]
# How can I decide which predictors to use in my model?

# %% [markdown]
# We'll explore a few methods in the sections below.

# %% [markdown]
# ## Correlation

# %% [markdown]
# Our first attempt might be just see which features are _correlated_ with the target to make a prediction.
#
# We can use the correlation metric in making a decision.

# %%
# Use the .corr() DataFrame method to find out about the
# correlation values between all pairs of variables!

wine.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000          0.219008     0.324436
# volatile acidity           0.219008          1.000000    -0.377981
# citric acid                0.324436         -0.377981     1.000000
# residual sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free sulfur dioxide       -0.282735         -0.352557     0.133126
# total sulfur dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
# red_wine                   0.486740          0.653036    -0.187397
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity              -0.111981   0.298195            -0.282735
# volatile acidity           -0.196011   0.377124            -0.352557
# citric acid                 0.142451   0.038998             0.133126
# residual sugar              1.000000  -0.128940             0.402871
# chlorides                  -0.128940   1.000000            -0.195045
# free sulfur dioxide         0.402871  -0.195045             1.000000
# total sulfur dioxide        0.495482  -0.279630             0.720934
# density                     0.552517   0.362615             0.025717
# pH                         -0.267320   0.044708            -0.145854
# sulphates                  -0.185927   0.395593            -0.188457
# alcohol                    -0.359415  -0.256916            -0.179838
# quality                    -0.036980  -0.200666             0.055463
# red_wine                   -0.348821   0.512678            -0.471644
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.329054  0.458910 -0.252700   0.299568
# volatile acidity                 -0.414476  0.271296  0.261454   0.225984
# citric acid                       0.195242  0.096154 -0.329808   0.056197
# residual sugar                    0.495482  0.552517 -0.267320  -0.185927
# chlorides                        -0.279630  0.362615  0.044708   0.395593
# free sulfur dioxide               0.720934  0.025717 -0.145854  -0.188457
# total sulfur dioxide              1.000000  0.032395 -0.238413  -0.275727
# density                           0.032395  1.000000  0.011686   0.259478
# pH                               -0.238413  0.011686  1.000000   0.192123
# sulphates                        -0.275727  0.259478  0.192123   1.000000
# alcohol                          -0.265740 -0.686745  0.121248  -0.003029
# quality                          -0.041385 -0.305858  0.019506   0.038485
# red_wine                         -0.700357  0.390645  0.329129   0.487218
#
#                        alcohol   quality  red_wine
# fixed acidity        -0.095452 -0.076743  0.486740
# volatile acidity     -0.037640 -0.265699  0.653036
# citric acid          -0.010493  0.085532 -0.187397
# residual sugar       -0.359415 -0.036980 -0.348821
# chlorides            -0.256916 -0.200666  0.512678
# free sulfur dioxide  -0.179838  0.055463 -0.471644
# total sulfur dioxide -0.265740 -0.041385 -0.700357
# density              -0.686745 -0.305858  0.390645
# pH                    0.121248  0.019506  0.329129
# sulphates            -0.003029  0.038485  0.487218
# alcohol               1.000000  0.444319 -0.032970
# quality               0.444319  1.000000 -0.119323
# red_wine             -0.032970 -0.119323  1.000000

# %%
sns.set(rc={'figure.figsize':(8, 8)})

# Use the .heatmap function to depict the relationships visually!
sns.heatmap(wine.corr(), annot=True);

# %%
# Let's look at the correlations with 'quality'
# (our dependent variable) in particular.

wine_corrs = wine.corr()['quality'].map(abs).sort_values(ascending=False)
wine_corrs
# Out:
# quality                 1.000000
# alcohol                 0.444319
# density                 0.305858
# volatile acidity        0.265699
# chlorides               0.200666
# red_wine                0.119323
# citric acid             0.085532
# fixed acidity           0.076743
# free sulfur dioxide     0.055463
# total sulfur dioxide    0.041385
# sulphates               0.038485
# residual sugar          0.036980
# pH                      0.019506
# Name: quality, dtype: float64

# %% [markdown]
# It looks like we can see the features have different correlations with the target. The larger the correlation, the more we'd expect these features to be better predictors.

# %% [markdown]
# Let's try using only a subset of the strongest correlated features to make our model.

# %%
# Let's choose 'alcohol' and 'density'.

wine_preds = wine[['alcohol', 'density']]
wine_target = wine['quality']
preds_with_const = sm.add_constant(wine_preds)

# %%
model = sm.OLS(endog=wine_target, exog=preds_with_const).fit()

# %%
model.rsquared
# Out:
# 0.19741993980311312

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.197
# Model:                            OLS   Adj. R-squared:                  0.197
# Method:                 Least Squares   F-statistic:                     798.7
# Date:                Tue, 12 Dec 2023   Prob (F-statistic):          7.48e-311
# Time:                        11:40:35   Log-Likelihood:                -7623.4
# No. Observations:                6497   AIC:                         1.525e+04
# Df Residuals:                    6494   BIC:                         1.527e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8095      4.512      0.623      0.533      -6.035      11.654
# alcohol        0.3246      0.011     28.991      0.000       0.303       0.347
# density       -0.3991      4.454     -0.090      0.929      -9.130       8.332
# ==============================================================================
# Omnibus:                      123.912   Durbin-Watson:                   1.636
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              258.761
# Skew:                           0.031   Prob(JB):                     6.47e-57
# Kurtosis:                       3.976   Cond. No.                     6.96e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.96e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# > Domain knowledge can be helpful here! 🧠

# %% [markdown]
# In practice this aspect of data preparation can constitute a huge part of the data scientist's work. As we move into data modeling, much of the goal will be a matter of finding––**or creating**––features that are predictive of the targets we are trying to model.
#
# There are infinitely many ways of transforming and combining a starting set of features. Good data scientists will have a nose for which engineering operations will be likely to yield fruit and for which operations won't. And part of the game here may be getting someone else on your team who understands what the data represent better than you!

# %% [markdown]
# ## Distribution Transformations

# %% [markdown]
# ### Log Scaling

# %% [markdown]
# Linear regression can work better if the predictor and target are normally distributed.
#
# **Log-scaling** can be a good tool to make *right-skewed* data more normal.
#
# (For *left-skewed* data, which is rarer, we can try transforming our data by raising it to an exponent greater than 1.)

# %% [markdown]
# Suppose e.g. a kde plot of my predictor $X$ looks like this:
#
# ![original](images/skewplot.png)

# %% [markdown]
# In that case, the kde plot of a log-transformed version of $X$ could look like this:
#
# ![log](images/logplot.png)

# %% [markdown]
# Let's set up a problem like this.

# %%
diamonds = sns.load_dataset('diamonds')

# %%
X = diamonds.select_dtypes(include=float)
y = diamonds['price']

# %%
X
# Out:
#        carat  depth  table     x     y     z
# 0       0.23   61.5   55.0  3.95  3.98  2.43
# 1       0.21   59.8   61.0  3.89  3.84  2.31
# 2       0.23   56.9   65.0  4.05  4.07  2.31
# 3       0.29   62.4   58.0  4.20  4.23  2.63
# 4       0.31   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   57.0  5.75  5.76  3.50
# 53936   0.72   63.1   55.0  5.69  5.75  3.61
# 53937   0.70   62.8   60.0  5.66  5.68  3.56
# 53938   0.86   61.0   58.0  6.15  6.12  3.74
# 53939   0.75   62.2   55.0  5.83  5.87  3.64
#
# [53940 rows x 6 columns]

# %% [markdown]
# ### Build model

# %%
sm.OLS(endog=y, exog=sm.add_constant(X)).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.859
# Method:                 Least Squares   F-statistic:                 5.486e+04
# Date:                Tue, 12 Dec 2023   Prob (F-statistic):               0.00
# Time:                        11:47:38   Log-Likelihood:            -4.7090e+05
# No. Observations:               53940   AIC:                         9.418e+05
# Df Residuals:                   53933   BIC:                         9.419e+05
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.085e+04    447.562     46.584      0.000       2e+04    2.17e+04
# carat       1.069e+04     63.201    169.085      0.000    1.06e+04    1.08e+04
# depth       -203.1541      5.504    -36.910      0.000    -213.942    -192.366
# table       -102.4457      3.084    -33.216      0.000    -108.491     -96.401
# x          -1315.6678     43.070    -30.547      0.000   -1400.086   -1231.250
# y             66.3216     25.523      2.599      0.009      16.296     116.347
# z             41.6277     44.305      0.940      0.347     -45.210     128.465
# ==============================================================================
# Omnibus:                    14093.399   Durbin-Watson:                   1.249
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           373568.966
# Skew:                           0.674   Prob(JB):                         0.00
# Kurtosis:                      15.822   Cond. No.                     5.91e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.91e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Check distribution of target

# %%
y.hist();

# %%
y_scld = np.log(y)
y_scld.hist();

# %%
np.exp(y_scld)
# Out:
# 0         326.0
# 1         326.0
# 2         327.0
# 3         334.0
# 4         335.0
#           ...
# 53935    2757.0
# 53936    2757.0
# 53937    2757.0
# 53938    2757.0
# 53939    2757.0
# Name: price, Length: 53940, dtype: float64

# %%
y
# Out:
# 0         326
# 1         326
# 2         327
# 3         334
# 4         335
#          ...
# 53935    2757
# 53936    2757
# 53937    2757
# 53938    2757
# 53939    2757
# Name: price, Length: 53940, dtype: int64

# %% [markdown]
# ### Build model with log-scaled target

# %%
model_diam = sm.OLS(y_scld, sm.add_constant(X)).fit()
model_diam.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.924
# Model:                            OLS   Adj. R-squared:                  0.924
# Method:                 Least Squares   F-statistic:                 1.095e+05
# Date:                Tue, 12 Dec 2023   Prob (F-statistic):               0.00
# Time:                        11:49:38   Log-Likelihood:                -7776.1
# No. Observations:               53940   AIC:                         1.557e+04
# Df Residuals:                   53933   BIC:                         1.563e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.8952      0.084     10.712      0.000       0.731       1.059
# carat         -0.7028      0.012    -59.551      0.000      -0.726      -0.680
# depth          0.0220      0.001     21.403      0.000       0.020       0.024
# table         -0.0098      0.001    -16.989      0.000      -0.011      -0.009
# x              1.0757      0.008    133.763      0.000       1.060       1.091
# y              0.0456      0.005      9.576      0.000       0.036       0.055
# z              0.0648      0.008      7.836      0.000       0.049       0.081
# ==============================================================================
# Omnibus:                    49564.202   Durbin-Watson:                   1.368
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):         24894704.347
# Skew:                           3.544   Prob(JB):                         0.00
# Kurtosis:                     108.007   Cond. No.                     5.91e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.91e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X['carat'].hist()
# Out:
# <Axes: >

# %%
X['table'].hist()
# Out:
# <Axes: >

# %%
X_copy = X.copy()
X_copy['carat'] = np.log(X_copy['carat'])
X_copy.head()
# Out:
#       carat  depth  table     x     y     z
# 0 -1.469676   61.5   55.0  3.95  3.98  2.43
# 1 -1.560648   59.8   61.0  3.89  3.84  2.31
# 2 -1.469676   56.9   65.0  4.05  4.07  2.31
# 3 -1.237874   62.4   58.0  4.20  4.23  2.63
# 4 -1.171183   63.3   58.0  4.34  4.35  2.75

# %%
X.head()
# Out:
#    carat  depth  table     x     y     z
# 0   0.23   61.5   55.0  3.95  3.98  2.43
# 1   0.21   59.8   61.0  3.89  3.84  2.31
# 2   0.23   56.9   65.0  4.05  4.07  2.31
# 3   0.29   62.4   58.0  4.20  4.23  2.63
# 4   0.31   63.3   58.0  4.34  4.35  2.75

# %%
model_diam = sm.OLS(y_scld, sm.add_constant(X_copy)).fit()
model_diam.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.935
# Model:                            OLS   Adj. R-squared:                  0.935
# Method:                 Least Squares   F-statistic:                 1.299e+05
# Date:                Tue, 12 Dec 2023   Prob (F-statistic):               0.00
# Time:                        11:54:35   Log-Likelihood:                -3481.6
# No. Observations:               53940   AIC:                             6977.
# Df Residuals:                   53933   BIC:                             7040.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         11.6143      0.104    111.987      0.000      11.411      11.818
# carat          1.7346      0.015    116.051      0.000       1.705       1.764
# depth         -0.0315      0.001    -31.717      0.000      -0.033      -0.030
# table         -0.0186      0.001    -34.745      0.000      -0.020      -0.018
# x             -0.0464      0.009     -4.905      0.000      -0.065      -0.028
# y              0.0077      0.004      1.753      0.080      -0.001       0.016
# z              0.0262      0.008      3.433      0.001       0.011       0.041
# ==============================================================================
# Omnibus:                      798.683   Durbin-Watson:                   1.242
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1429.174
# Skew:                           0.091   Prob(JB):                    4.56e-311
# Kurtosis:                       3.776   Cond. No.                     7.98e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.98e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
sns.pairplot(diamonds)

# %% [markdown]
# ### Interpreting Log-Transformed Coefficients

# %% [markdown]
# But with this transformed target, how do I now interpret my LR coefficients?
#
# Before the transformation, I would have said that a one-unit increase in, say, depth results on average in a 0.0319 increase in price. But what I need to say now is that a one-unit increase in depth results on average in a 0.0319 increase *in the logarithm of price*, i.e. an increase in price by a factor of $e^{0.0319}$.

# %%
print(f"""
A one-unit increase in the depth variable corresponds
to an increase in price by a factor of {round(np.exp(0.0319), 3)},
or {100 * round(np.exp(0.0319) - 1, 3)}%.
""")
# Out:
# A one-unit increase in the depth variable corresponds
# to an increase in price by a factor of 1.032,
# or 3.2%.

# %% [markdown]
# For more on this, including how to interpret coefficients after log-transforming *independent* variables, check out [this resource](https://data.library.virginia.edu/interpreting-log-transformations-in-a-linear-model/).

# %% [markdown]
# ## Binning

# %% [markdown]
# To start we'll look at some `seaborn` Pair Plots. We'll do this in two halves so that we can see things a bit more clearly:

# %%
# This will show the first six predictors and 'quality'
columns = [True if j < 6 or j == 11 else False for j in range(13)]

sns.pairplot(data=wine.iloc[:, columns]);

# %%
sns.pairplot(data=wine.iloc[:, 6:]);

# %% [markdown]
# ### Volatile Acidity

# %% [markdown]
# Let's look at the distribution of the volatile acidity feature:

# %%
wine['volatile acidity'].hist();

# %% [markdown]
# Suppose we add more bins:

# %%
wine['volatile acidity'].hist(bins=50);

# %%
wine['volatile acidity'].hist(bins='auto');

# %% [markdown]
# Now the distribution looks quite different. There seems to be a small second peak around 0.6. And we can reproduce this if we check out `seaborn`'s kernel density plot.

# %%
sns.kdeplot(wine['volatile acidity']);

# %% [markdown]
# So suppose we build a new feature that records whether a wine's volatile acidity is above 0.5.

# %%
wine['high_va'] = wine['volatile acidity'] > .55

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  red_wine  high_va
# 0      9.4        5         1     True
# 1      9.8        5         1     True
# 2      9.8        5         1     True
# 3      9.8        6         1    False
# 4      9.4        5         1     True

# %%
wine.corr()['quality']['high_va']
# Out:
# -0.217422170005528

# %%
# Now we can build a new model with this feature.

wine_preds2 = wine[['alcohol', 'density', 'high_va']]

# %%
lr2 = LinearRegression().fit(wine_preds2, wine_target)

# %%
lr2.score(wine_preds2, wine_target)
# Out:
# 0.23109373356469876

# %%
lr2.coef_
# Out:
# array([ 0.3422338 , 16.89253911, -0.50264401])

# %% [markdown]
# Not bad! We don't seem to have stumbled onto a huge connection here, but this correlation value suggests that this new feature may be helpful in a final model.

# %% [markdown]
# ### $\bf{SO_2}$

# %% [markdown]
# Next we'll take a look at distribution of the sulfur dioxide feature:

# %%
wine['total sulfur dioxide'].hist(bins=35);

# %% [markdown]
# Let's try separating our wines into those with sulfur dioxide higher than 80 and those with less:

# %%
wine['high_so2'] = wine['total sulfur dioxide'] > 80

# %%
wine.corr()['quality']['high_so2']
# Out:
# 0.08074521567590653

# %% [markdown]
# Not great. Perhaps this is a modeling dead end.

# %% [markdown]
# ## Products of Features

# %% [markdown]
# Another engineering strategy we might try is **multiplying features together**.

# %% [markdown]
# Let's try these two features: `residual sugar` and `total sulfur dioxide`. Note that without domain knowledge or exploration, this is really a guess that this combination will predict `quality` well.

# %%
wine['rs*tsd'] = wine['residual sugar'] * wine['total sulfur dioxide']

# %%
wine.corr()['quality']['rs*tsd']
# Out:
# -0.06622845877790014

# %%
wine.corr()['quality']['residual sugar']
# Out:
# -0.036980484585769566

# %%
wine.corr()['quality']['total sulfur dioxide']
# Out:
# -0.041385453855609024

# %% [markdown]
# We can see these two features together have a higher correlation than each by itself!

# %% [markdown]
# ## Polynomial Features

# %% [markdown]
# Instead of just multiplying features at random, we might consider trying **every possible product of features**. That's what PolynomialFeatures does:

# %%
pf = PolynomialFeatures(degree=3)

X = wine.drop(['quality'], axis=1)
y = wine['quality']

# Fitting the PolynomialFeatures object
pf.fit(X)
# Out:
# PolynomialFeatures(degree=3)

# %%
X.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  red_wine  high_va  high_so2  rs*tsd
# 0      9.4         1     True     False    64.6
# 1      9.8         1     True     False   174.2
# 2      9.8         1     True     False   124.2
# 3      9.8         1    False     False   114.0
# 4      9.4         1     True     False    64.6

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  red_wine  high_va  high_so2  rs*tsd
# 0      9.4        5         1     True     False    64.6
# 1      9.8        5         1     True     False   174.2
# 2      9.8        5         1     True     False   124.2
# 3      9.8        6         1    False     False   114.0
# 4      9.4        5         1     True     False    64.6

# %%
X.shape
# Out:
# (6497, 15)

# %%
pf.transform(X)
# Out:
# array([[1.00000000e+00, 7.40000000e+00, 7.00000000e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 2.69586136e+05],
#        [1.00000000e+00, 7.80000000e+00, 8.80000000e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 5.28621049e+06],
#        [1.00000000e+00, 7.80000000e+00, 7.60000000e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 1.91586449e+06],
#        ...,
#        [1.00000000e+00, 6.50000000e+00, 2.40000000e-01, ...,
#         1.33200000e+02, 1.77422400e+04, 2.36326637e+06],
#        [1.00000000e+00, 5.50000000e+00, 2.90000000e-01, ...,
#         1.21000000e+02, 1.46410000e+04, 1.77156100e+06],
#        [1.00000000e+00, 6.00000000e+00, 2.10000000e-01, ...,
#         7.84000000e+01, 6.14656000e+03, 4.81890304e+05]])

# %%
pdf = pd.DataFrame(pf.transform(X), columns=pf.get_feature_names_out())
pdf
# Out:
#         1  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     1.0            7.4              0.70         0.00             1.9
# 1     1.0            7.8              0.88         0.00             2.6
# 2     1.0            7.8              0.76         0.04             2.3
# 3     1.0           11.2              0.28         0.56             1.9
# 4     1.0            7.4              0.70         0.00             1.9
# ...   ...            ...               ...          ...             ...
# 6492  1.0            6.2              0.21         0.29             1.6
# 6493  1.0            6.6              0.32         0.36             8.0
# 6494  1.0            6.5              0.24         0.19             1.2
# 6495  1.0            5.5              0.29         0.30             1.1
# 6496  1.0            6.0              0.21         0.38             0.8
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0         0.076                 11.0                  34.0  0.99780  3.51
# 1         0.098                 25.0                  67.0  0.99680  3.20
# 2         0.092                 15.0                  54.0  0.99700  3.26
# 3         0.075                 17.0                  60.0  0.99800  3.16
# 4         0.076                 11.0                  34.0  0.99780  3.51
# ...         ...                  ...                   ...      ...   ...
# 6492      0.039                 24.0                  92.0  0.99114  3.27
# 6493      0.047                 57.0                 168.0  0.99490  3.15
# 6494      0.041                 30.0                 111.0  0.99254  2.99
# 6495      0.022                 20.0                 110.0  0.98869  3.34
# 6496      0.020                 22.0                  98.0  0.98941  3.26
#
#       ...  high_va^3  high_va^2 high_so2  high_va^2 rs*tsd  \
# 0     ...        1.0                 0.0              64.6
# 1     ...        1.0                 0.0             174.2
# 2     ...        1.0                 0.0             124.2
# 3     ...        0.0                 0.0               0.0
# 4     ...        1.0                 0.0              64.6
# ...   ...        ...                 ...               ...
# 6492  ...        0.0                 0.0               0.0
# 6493  ...        0.0                 0.0               0.0
# 6494  ...        0.0                 0.0               0.0
# 6495  ...        0.0                 0.0               0.0
# 6496  ...        0.0                 0.0               0.0
#
#       high_va high_so2^2  high_va high_so2 rs*tsd  high_va rs*tsd^2  \
# 0                    0.0                      0.0           4173.16
# 1                    0.0                      0.0          30345.64
# 2                    0.0                      0.0          15425.64
# 3                    0.0                      0.0              0.00
# 4                    0.0                      0.0           4173.16
# ...                  ...                      ...               ...
# 6492                 0.0                      0.0              0.00
# 6493                 0.0                      0.0              0.00
# 6494                 0.0                      0.0              0.00
# 6495                 0.0                      0.0              0.00
# 6496                 0.0                      0.0              0.00
#
#       high_so2^3  high_so2^2 rs*tsd  high_so2 rs*tsd^2      rs*tsd^3
# 0            0.0                0.0               0.00  2.695861e+05
# 1            0.0                0.0               0.00  5.286210e+06
# 2            0.0                0.0               0.00  1.915864e+06
# 3            0.0                0.0               0.00  1.481544e+06
# 4            0.0                0.0               0.00  2.695861e+05
# ...          ...                ...                ...           ...
# 6492         1.0              147.2           21667.84  3.189506e+06
# 6493         1.0             1344.0         1806336.00  2.427716e+09
# 6494         1.0              133.2           17742.24  2.363266e+06
# 6495         1.0              121.0           14641.00  1.771561e+06
# 6496         1.0               78.4            6146.56  4.818903e+05
#
# [6497 rows x 816 columns]

# %%
pdf.shape
# Out:
# (6497, 816)

# %%
pdf2 = pdf.drop(columns=['1'])

# %%
lr = LinearRegression()

lr.fit(pdf2, y)
# Out:
# LinearRegression()

# %%
lr.score(pdf2, y)
# Out:
# 0.48248975764922997

# %%
lr.intercept_
# Out:
# 228.3177850317521

# %%
lr.coef_
# Out:
# array([ 1.37573419e+01, -5.75423807e+01, -4.13759836e+02,  3.78241047e+02,
#        -2.42775081e+02, -3.69081136e+01,  8.72188339e+00, -2.84192643e+01,
#         2.02958804e+02,  2.62459719e+02, -2.86500114e+02,  1.37953279e+02,
#         4.22815490e+02, -1.66346218e+02, -4.39384190e+00,  5.58501792e+00,
#        -1.21514484e+02, -3.77802094e+02, -2.66793872e+01,  2.07033791e+02,
#        -3.24631910e+00, -7.29690693e-01,  2.12619867e+02, -1.30342654e+02,
#         2.87115260e+02,  3.30711051e+01, -6.47564361e+01, -3.77271585e+01,
#         8.74401855e+00,  3.82105282e-02,  3.41412080e+02,  9.68160515e+01,
#         2.72084217e+02, -1.61879966e+02,  2.05963990e+01,  5.97983418e+00,
#         6.62778146e+00, -6.89916991e+02,  6.46038312e+02,  3.72279414e+01,
#         4.52068975e+02,  1.90012167e+02,  3.93735198e+02, -9.36973246e-01,
#         2.46602544e+03,  9.09953161e+01, -2.04250763e+01,  3.29886208e+00,
#         3.17286915e+01,  6.83213037e+01,  1.66471671e+02, -1.67294337e+03,
#        -1.56712700e+02,  1.26764928e+03,  3.15663951e+02, -3.10056911e+02,
#        -4.30159523e-01, -3.56750561e+00,  3.49972440e+03, -2.21635383e-02,
#        -4.34496045e+00,  6.42336814e+01, -1.92912906e+02, -6.03175282e+01,
#        -9.69065675e+00, -1.60883604e+02,  6.82887212e+01, -7.33329837e+01,
fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                quality   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.459
# Method:                 Least Squares   F-statistic:                     11.25
# Date:                Tue, 12 Dec 2023   Prob (F-statistic):               0.00
# Time:                        12:18:15   Log-Likelihood:                -6060.3
# No. Observations:                6497   AIC:                         1.320e+04
# Df Residuals:                    5958   BIC:                         1.685e+04
# Df Model:                         538
# Covariance Type:            nonrobust
# =============================================================================================================================
#                                                                 coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------------
# 1                                                           -17.9979    102.850     -0.175      0.861    -219.620     183.625
# fixed acidity                                              -125.1654    162.333     -0.771      0.441    -443.398     193.067
# volatile acidity                                             25.0451     43.178      0.580      0.562     -59.600     109.690
# citric acid                                                 -16.3419     32.262     -0.507      0.612     -79.587      46.903
# residual sugar                                              191.3054    110.954      1.724      0.085     -26.205     408.815
# chlorides                                                  -150.7167    179.783     -0.838      0.402    -503.156     201.722
# free sulfur dioxide                                         -28.2347     28.577     -0.988      0.323     -84.255      27.786
# total sulfur dioxide                                        -54.7784     37.435     -1.463      0.143    -128.164      18.607
# density                                                      18.9177     39.532      0.479      0.632     -58.579      96.414
# pH                                                           66.6658     82.169      0.811      0.417     -94.415     227.747
# sulphates                                                   -78.1358     33.076     -2.362      0.018    -142.976     -13.296
# alcohol                                                     172.5744    121.695      1.418      0.156     -65.992     411.140
# red_wine                                                   -122.0909     52.026     -2.347      0.019    -224.081     -20.100
# high_va                                                      66.9238     50.325      1.330      0.184     -31.731     165.579
# high_so2                                                     27.6745     32.936      0.840      0.401     -36.892      92.241
# rs*tsd                                                       -0.7464      8.981     -0.083      0.934     -18.353      16.860
# fixed acidity^2                                               6.5024      7.970      0.816      0.415      -9.122      22.127
# fixed acidity volatile acidity                              -36.7736    117.628     -0.313      0.755    -267.367     193.819
# fixed acidity citric acid                                   -22.9654     97.828     -0.235      0.814    -214.743     168.813
# fixed acidity residual sugar                                -11.3325     17.327     -0.654      0.513     -45.299      22.634
# fixed acidity chlorides                                      52.0640     78.432      0.664      0.507    -101.691     205.819
# fixed acidity free sulfur dioxide                            -2.5019      1.879     -1.331      0.183      -6.185       1.182
# fixed acidity total sulfur dioxide                           -0.6043      0.950     -0.636      0.525      -2.467       1.259
# fixed acidity density                                        15.3646      9.208      1.669      0.095      -2.687      33.416
# fixed acidity pH                                             -4.2751     91.890     -0.047      0.963    -184.414     175.863
# fixed acidity sulphates                                     162.7222     92.850      1.753      0.080     -19.297     344.741
# fixed acidity alcohol                                        18.6549     13.572      1.374      0.169      -7.952      45.262
# fixed acidity red_wine                                      -30.1315     36.312     -0.830      0.407    -101.316      41.053
# fixed acidity high_va                                         8.6494     25.413      0.340      0.734     -41.169      58.468
# fixed acidity high_so2                                       -8.8803     34.405     -0.258      0.796     -76.326      58.566
# density rs*tsd                                                0.6609     18.334      0.036      0.971     -35.280      36.601
# pH^2                                                        -32.9069    132.508     -0.248      0.804    -292.670     226.857
# pH sulphates                                               -124.3917     62.515     -1.990      0.047    -246.945      -1.839
# pH alcohol                                                   20.4043     95.761      0.213      0.831    -167.323     208.131
# pH red_wine                                                -219.7732     92.261     -2.382      0.017    -400.639     -38.908
# pH high_va                                                  107.5179     85.640      1.255      0.209     -60.368     275.404
# pH high_so2                                                  11.9452     82.208      0.145      0.884    -149.212     173.103
# pH rs*tsd                                                    -0.0155      0.317     -0.049      0.961      -0.637       0.606
# sulphates^2                                                 -43.5704     33.524     -1.300      0.194    -109.290      22.149
# sulphates alcohol                                           -59.9724     92.828     -0.646      0.518    -241.949     122.005
# sulphates red_wine                                          -58.2854     49.606     -1.175      0.240    -155.532      38.961
# sulphates high_va                                           -89.3457     75.415     -1.185      0.236    -237.187      58.496
# sulphates high_so2                                          -19.7011     25.219     -0.781      0.435     -69.140      29.737
# sulphates rs*tsd                                              0.0261      0.574      0.045      0.964      -1.100       1.152
# alcohol^2                                                   -23.3978     14.537     -1.610      0.108     -51.895       5.100
# alcohol red_wine                                            104.5350     36.623      2.854      0.004      32.740     176.330
# alcohol high_va                                             -41.1791     36.287     -1.135      0.256    -112.315      29.957
# alcohol high_so2                                             54.4004     33.796      1.610      0.108     -11.852     120.653
# alcohol rs*tsd                                                0.0564      0.077      0.737      0.461      -0.094       0.206
# red_wine^2                                                 -122.0912     52.027     -2.347      0.019    -224.082     -20.100
# red_wine high_va                                           -117.2153     85.153     -1.377      0.169    -284.147      49.716
# red_wine high_so2                                           -83.8688     79.404     -1.056      0.291    -239.529      71.792
# red_wine rs*tsd                                               0.6133      0.685      0.896      0.370      -0.729       1.956
# high_va^2                                                    66.9228     50.325      1.330      0.184     -31.732     165.578
# high_va high_so2                                             33.4866     86.636      0.387      0.699    -136.351     203.325
# high_va rs*tsd                                               -0.1317      0.253     -0.520      0.603      -0.628       0.365
# high_so2^2                                                   27.6745     32.936      0.840      0.401     -36.892      92.241
# high_so2 rs*tsd                                               0.9035      0.660      1.369      0.171      -0.390       2.197
# rs*tsd^2                                                     4.2e-05      0.000      0.150      0.881      -0.001       0.001
# fixed acidity^3                                              -0.0030      0.006     -0.479      0.632      -0.015       0.009
# fixed acidity^2 volatile acidity                              0.0720      0.144      0.499      0.618      -0.211       0.355
# fixed acidity^2 citric acid                                   0.3285      0.120      2.743      0.006       0.094       0.563
# fixed acidity^2 residual sugar                                0.0013      0.017      0.080      0.936      -0.032       0.034
# fixed acidity^2 chlorides                                    -0.8110      0.564     -1.438      0.150      -1.917       0.295
# fixed acidity^2 free sulfur dioxide                          -0.0011      0.002     -0.600      0.548      -0.004       0.002
# fixed acidity^2 total sulfur dioxide                      -6.303e-05      0.001     -0.068      0.946      -0.002       0.002
# fixed acidity^2 density                                      -6.7327      8.120     -0.829      0.407     -22.651       9.186
# fixed acidity^2 pH                                           -0.0265      0.117     -0.227      0.820      -0.255       0.202
# fixed acidity^2 sulphates                                     0.1590      0.112      1.425      0.154      -0.060       0.378
# fixed acidity residual sugar total sulfur dioxide             0.0241      0.060      0.399      0.690      -0.094       0.143
# fixed acidity residual sugar density                         10.5779     17.671      0.599      0.549     -24.063      45.219
# fixed acidity residual sugar pH                               0.2017      0.149      1.349      0.177      -0.091       0.495
# fixed acidity residual sugar sulphates                       -0.0598      0.181     -0.331      0.741      -0.414       0.294
# fixed acidity residual sugar alcohol                          0.0213      0.030      0.723      0.469      -0.036       0.079
# fixed acidity residual sugar red_wine                         0.0305      0.176      0.173      0.862      -0.314       0.375
# fixed acidity residual sugar high_va                          0.0338      0.124      0.272      0.785      -0.209       0.277
# fixed acidity residual sugar high_so2                        -0.1718      0.167     -1.031      0.303      -0.498       0.155
# fixed acidity residual sugar rs*tsd                       -1.477e-05      0.000     -0.099      0.921      -0.000       0.000
# fixed acidity chlorides^2                                    -2.5277      8.608     -0.294      0.769     -19.402      14.347
# fixed acidity chlorides free sulfur dioxide                   0.1141      0.107      1.065      0.287      -0.096       0.324
# fixed acidity chlorides total sulfur dioxide                 -0.1053      0.061     -1.731      0.083      -0.225       0.014
# fixed acidity chlorides density                             -15.2013     81.158     -0.187      0.851    -174.299     143.897
# fixed acidity chlorides pH                                   -4.6016      6.686     -0.688      0.491     -17.708       8.505
# fixed acidity chlorides sulphates                            -7.7800      5.229     -1.488      0.137     -18.031       2.471
# fixed acidity chlorides alcohol                              -0.4945      0.753     -0.657      0.511      -1.971       0.982
# fixed acidity chlorides red_wine                              2.4295      4.611      0.527      0.598      -6.610      11.469
# fixed acidity chlorides high_va                              -2.6653      2.863     -0.931      0.352      -8.277       2.946
# fixed acidity chlorides high_so2                              0.9289      3.634      0.256      0.798      -6.194       8.052
# fixed acidity chlorides rs*tsd                                0.0166      0.007      2.426      0.015       0.003       0.030
# fixed acidity free sulfur dioxide^2                          -0.0001   7.85e-05     -1.634      0.102      -0.000    2.56e-05
# fixed acidity free sulfur dioxide total sulfur dioxide     2.817e-05      0.000      0.280      0.780      -0.000       0.000
# fixed acidity free sulfur dioxide density                     2.4553      1.931      1.272      0.204      -1.330       6.240
# fixed acidity free sulfur dioxide pH                          0.0187      0.017      1.073      0.283      -0.015       0.053
# fixed acidity free sulfur dioxide sulphates                   0.0211      0.014      1.492      0.136      -0.007       0.049
# fixed acidity free sulfur dioxide alcohol                     0.0001      0.003      0.047      0.963      -0.006       0.006
# fixed acidity free sulfur dioxide red_wine                   -0.0319      0.014     -2.288      0.022      -0.059      -0.005
# fixed acidity free sulfur dioxide high_va                    -0.0035      0.012     -0.297      0.767      -0.026       0.019
# fixed acidity free sulfur dioxide high_so2                    0.0013      0.011      0.113      0.910      -0.021       0.024
# fixed acidity free sulfur dioxide rs*tsd                  -3.172e-06   1.08e-05     -0.293      0.770   -2.44e-05    1.81e-05
# fixed acidity total sulfur dioxide^2                       8.665e-05   4.37e-05      1.985      0.047    1.06e-06       0.000
# fixed acidity total sulfur dioxide density                    0.5758      0.971      0.593      0.553      -1.327       2.478
# fixed acidity total sulfur dioxide pH                        -0.0029      0.009     -0.330      0.741      -0.020       0.014
# fixed acidity total sulfur dioxide sulphates                 -0.0075      0.008     -0.894      0.371      -0.024       0.009
# fixed acidity total sulfur dioxide alcohol                    0.0028      0.002      1.761      0.078      -0.000       0.006
# fixed acidity total sulfur dioxide red_wine                   0.0223      0.008      2.704      0.007       0.006       0.039
# fixed acidity total sulfur dioxide high_va                   -0.0061      0.006     -1.066      0.286      -0.017       0.005
# fixed acidity total sulfur dioxide high_so2                  -0.0085      0.009     -0.982      0.326      -0.025       0.008
# fixed acidity total sulfur dioxide rs*tsd                 -5.042e-06   9.29e-06     -0.543      0.587   -2.33e-05    1.32e-05
# fixed acidity density^2                                     120.7020    163.653      0.738      0.461    -200.117     441.521
# fixed acidity density pH                                      2.7108     93.826      0.029      0.977    -181.221     186.643
# fixed acidity density sulphates                            -165.8533     94.846     -1.749      0.080    -351.786      20.080
# fixed acidity density alcohol                               -18.7928     13.870     -1.355      0.175     -45.982       8.397
# fixed acidity density red_wine                               59.0337     73.726      0.801      0.423     -85.496     203.564
# fixed acidity density high_va                               -15.3471     52.161     -0.294      0.769    -117.601      86.907
# fixed acidity density high_so2                               18.8534     70.168      0.269      0.788    -118.701     156.408
# fixed acidity density rs*tsd                                 -0.0422      0.123     -0.342      0.732      -0.284       0.200
# fixed acidity pH^2                                           -0.3183      0.657     -0.485      0.628      -1.606       0.969
# fixed acidity pH sulphates                                    0.5489      1.026      0.535      0.593      -1.463       2.561
# fixed acidity pH alcohol                                      0.2615      0.211      1.237      0.216      -0.153       0.676
# fixed acidity pH red_wine                                    -0.3445      0.849     -0.406      0.685      -2.008       1.319
# fixed acidity pH high_va                                     -0.4637      0.729     -0.636      0.525      -1.893       0.965
# fixed acidity pH high_so2                                     0.0882      0.607      0.145      0.884      -1.102       1.278
# fixed acidity pH rs*tsd                                      -0.0014      0.001     -1.375      0.169      -0.003       0.001
# fixed acidity sulphates^2                                    -0.9270      0.422     -2.197      0.028      -1.754      -0.100
# fixed acidity sulphates alcohol                              -0.1635      0.187     -0.873      0.383      -0.531       0.204
# fixed acidity sulphates red_wine                              1.0794      0.640      1.685      0.092      -0.176       2.335
# fixed acidity sulphates high_va                               0.7051      0.524      1.346      0.178      -0.322       1.732
# fixed acidity sulphates high_so2                              0.9471      0.523      1.811      0.070      -0.078       1.972
# fixed acidity sulphates rs*tsd                                0.0001      0.001      0.119      0.906      -0.002       0.002
# fixed acidity alcohol^2                                      -0.0537      0.023     -2.296      0.022      -0.100      -0.008
# fixed acidity alcohol red_wine                                0.1587      0.132      1.199      0.231      -0.101       0.418
# fixed acidity alcohol high_va                                 0.0295      0.110      0.269      0.788      -0.186       0.245
# fixed acidity alcohol high_so2                               -0.0268      0.117     -0.229      0.819      -0.256       0.203
# fixed acidity alcohol rs*tsd                                 -0.0002      0.000     -0.879      0.380      -0.001       0.000
# fixed acidity red_wine^2                                    -30.1315     36.312     -0.830      0.407    -101.316      41.053
# fixed acidity red_wine high_va                               -0.1170      0.424     -0.276      0.783      -0.948       0.714
# fixed acidity red_wine high_so2                              -1.0109      0.397     -2.545      0.011      -1.789      -0.232
# pH high_va^2                                                107.5179     85.640      1.255      0.209     -60.368     275.404
# pH high_va high_so2                                           1.6798      2.536      0.662      0.508      -3.292       6.652
# pH high_va rs*tsd                                             0.0048      0.005      0.957      0.339      -0.005       0.015
# pH high_so2^2                                                11.9452     82.208      0.145      0.884    -149.212     173.103
# pH high_so2 rs*tsd                                            0.0167      0.014      1.201      0.230      -0.011       0.044
# pH rs*tsd^2                                                2.019e-06   3.07e-06      0.658      0.510   -3.99e-06    8.03e-06
# sulphates^3                                                   3.4480      1.368      2.520      0.012       0.766       6.130
# sulphates^2 alcohol                                          -0.4114      0.463     -0.888      0.375      -1.320       0.497
# sulphates^2 red_wine                                         -2.0732      2.602     -0.797      0.426      -7.174       3.028
# sulphates^2 high_va                                           2.5969      2.105      1.234      0.217      -1.529       6.723
# sulphates^2 high_so2                                         -1.0650      2.121     -0.502      0.616      -5.224       3.094
# sulphates^2 rs*tsd                                            0.0017      0.004      0.408      0.683      -0.006       0.010
# sulphates alcohol^2                                          -0.0241      0.125     -0.193      0.847      -0.270       0.222
# sulphates alcohol red_wine                                    0.2703      0.622      0.434      0.664      -0.950       1.490
# sulphates alcohol high_va                                    -0.3378      0.513     -0.659      0.510      -1.343       0.668
# sulphates alcohol high_so2                                    1.0228      0.458      2.235      0.025       0.125       1.920
# sulphates alcohol rs*tsd                                      0.0018      0.002      1.197      0.232      -0.001       0.005
# sulphates red_wine^2                                        -58.2854     49.606     -1.175      0.240    -155.532      38.961
# sulphates red_wine high_va                                   -1.7151      2.624     -0.653      0.513      -6.860       3.430
# sulphates red_wine high_so2                                  -2.3907      2.230     -1.072      0.284      -6.763       1.982
# sulphates red_wine rs*tsd                                    -0.0044      0.010     -0.449      0.653      -0.023       0.015
# sulphates high_va^2                                         -89.3457     75.415     -1.185      0.236    -237.187      58.496
# sulphates high_va high_so2                                    0.5841      2.470      0.236      0.813      -4.258       5.426
# sulphates high_va rs*tsd                                     -0.0016      0.004     -0.367      0.713      -0.010       0.007
# sulphates high_so2^2                                        -19.7011     25.219     -0.781      0.435     -69.140      29.737
# sulphates high_so2 rs*tsd                                    -0.0252      0.014     -1.814      0.070      -0.052       0.002
# sulphates rs*tsd^2                                        -1.819e-06      3e-06     -0.606      0.545    -7.7e-06    4.07e-06
# alcohol^3                                                     0.0113      0.017      0.675      0.500      -0.021       0.044
# alcohol^2 red_wine                                           -0.3197      0.097     -3.305      0.001      -0.509      -0.130
# alcohol^2 high_va                                             0.0705      0.087      0.808      0.419      -0.101       0.241
# alcohol^2 high_so2                                           -0.2759      0.084     -3.269      0.001      -0.441      -0.110
# alcohol^2 rs*tsd                                             -0.0001      0.000     -0.856      0.392      -0.000       0.000
# alcohol red_wine^2                                          104.5350     36.623      2.854      0.004      32.740     176.330
# alcohol red_wine high_va                                     -0.0677      0.431     -0.157      0.875      -0.913       0.777
# alcohol red_wine high_so2                                     0.6414      0.419      1.529      0.126      -0.181       1.463
# alcohol red_wine rs*tsd                                      -0.0033      0.003     -1.237      0.216      -0.009       0.002
# alcohol high_va^2                                           -41.1791     36.287     -1.135      0.256    -112.315      29.957
# alcohol high_va high_so2                                     -0.4077      0.362     -1.126      0.260      -1.117       0.302
# alcohol high_va rs*tsd                                        0.0003      0.001      0.288      0.773      -0.002       0.002
# alcohol high_so2^2                                           54.4004     33.796      1.610      0.108     -11.852     120.653
# alcohol high_so2 rs*tsd                                      -0.0032      0.003     -1.226      0.220      -0.008       0.002
# alcohol rs*tsd^2                                           3.972e-08   6.32e-07      0.063      0.950    -1.2e-06    1.28e-06
# red_wine^3                                                 -122.0912     52.027     -2.347      0.019    -224.082     -20.100
# red_wine^2 high_va                                         -117.2153     85.153     -1.377      0.169    -284.147      49.716
# red_wine^2 high_so2                                         -83.8688     79.404     -1.056      0.291    -239.529      71.792
# red_wine^2 rs*tsd                                             0.6133      0.685      0.896      0.370      -0.729       1.956
# red_wine high_va^2                                         -117.2153     85.153     -1.377      0.169    -284.147      49.716
# red_wine high_va high_so2                                     0.1920      1.209      0.159      0.874      -2.179       2.563
# red_wine high_va rs*tsd                                      -0.0022      0.005     -0.440      0.660      -0.012       0.008
# red_wine high_so2^2                                         -83.8688     79.404     -1.056      0.291    -239.529      71.792
# red_wine high_so2 rs*tsd                                      0.0174      0.010      1.818      0.069      -0.001       0.036
# red_wine rs*tsd^2                                         -5.185e-06   8.55e-06     -0.606      0.544   -2.19e-05    1.16e-05
# high_va^3                                                    66.9228     50.325      1.330      0.184     -31.732     165.578
# high_va^2 high_so2                                           33.4866     86.636      0.387      0.699    -136.351     203.325
# high_va^2 rs*tsd                                             -0.1317      0.253     -0.520      0.603      -0.628       0.365
# high_va high_so2^2                                           33.4866     86.636      0.387      0.699    -136.351     203.325
# high_va high_so2 rs*tsd                                       0.0195      0.008      2.464      0.014       0.004       0.035
# high_va rs*tsd^2                                           9.161e-06   2.28e-06      4.019      0.000    4.69e-06    1.36e-05
# high_so2^3                                                   27.6745     32.936      0.840      0.401     -36.892      92.241
# high_so2^2 rs*tsd                                             0.9035      0.660      1.369      0.171      -0.390       2.197
# high_so2 rs*tsd^2                                          1.592e-05   1.75e-05      0.911      0.363   -1.84e-05    5.02e-05
# rs*tsd^3                                                  -1.016e-09   7.35e-10     -1.382      0.167   -2.46e-09    4.26e-10
# ==============================================================================
# Omnibus:                      100.646   Durbin-Watson:                   1.703
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              190.682
# Skew:                           0.047   Prob(JB):                     3.93e-42
# Kurtosis:                       3.834   Cond. No.                     4.43e+17
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is  1e-11. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %% [markdown]
# So: Is this a good idea? What are the potential dangers here?

# %% [markdown]
# ## Exercise

# %% [markdown]
# Consider the following dataset:

# %%
sales = pd.read_csv('data/Advertising.csv', index_col=0)

sales.head()

# %% [markdown]
# We'd like to try to understand sales as a function of spending on various media (TV, radio, newspaper).

# %%
sales.corr()['sales']

# %% [markdown]
# **Try to find the best multiplicative combination of features.**
#
# You may use `PolynomialFeatures` or just multiply by hand.

# %% [markdown]
# In practice, it's not easy to tell when such products of features will be so fruitful. Moreover, there is room for concern about violating regression's demand for feature independence. At the very least, we would probably not want to include a product *and the individual features themselves* in a final model, not if our goal is to understand what's really responsible for fluctuations in our target variable.
